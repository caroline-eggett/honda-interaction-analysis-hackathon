# %%
# %run dataframe.ipynb
# Out:
# Host Shape: rows: 4816389 and columns: 29
# Summary Shape: rows: 2611 and columns: 33
# EvtWarn Shape: rows: 39992 and columns: 36
# RvBsm Shape: rows: 491 and columns: 18
# Spat Shape: rows: 19389 and columns: 11

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_host_subset = df_host.sample(n=1000000)

# %%
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(3, 3, figsize=(20,10))
figure.tight_layout(pad=3.0)

# For Headlamp and wiper Correlation Function
axis[0, 0].scatter(df_host_subset['headlamp'], df_host_subset['wiper'])
axis[0, 0].set_title("Headlamp affects Wiper")
axis[0, 0].set_xlabel("Headlamp")
axis[0, 0].set_ylabel("Wiper")

# For Turn Signal and Stability Control
axis[1, 0].scatter(df_host_subset['tu'], df_host_subset['wiper'])
axis[1, 0].set_title("Headlamp affects Wiper")
axis[1, 0].set_xlabel("Headlamp")
axis[1, 0].set_ylabel("Wiper")
# Out:
# Text(153.125, 0.5, 'Wiper')
